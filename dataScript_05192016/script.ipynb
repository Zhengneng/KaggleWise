# %%
import pandas as pd
df = pd.read_csv("datatest.csv", header = None)

# %%
for i in xrange(len(df)):
    if df.iloc[i, 0] == 'Time':
        header = df.iloc[i].tolist()
        row_skip = i + 2
        break

# %%
df = pd.read_csv("datatest.csv", names = header, skiprows = row_skip)

# %%
df
# Out:
#        Time               IAS CITY_FROM_R CITY_TO_R     DATE_R  EGT1  EGT2  \
# 0   6:06:21    45  45  45  45                         00/00/00   296   147
# 1   6:06:22    45  45  45  45                         00/00/00   768   146
# 2   6:06:23    45  45  45  45                     G   00/00/00   296   150
# 3   6:06:24    45  45  45  45                         00/00/00     0   184
# 4   6:06:25    45  45  45  45                         00/00/00   296   217
# 5   6:06:26    45  45  45  45                         00/00/00   768   249
# 6   6:06:27    45  45  45  45                    ZG   00/00/00   296   279
# 7   6:06:28    45  45  45  45                         00/00/00     0   306
# 8   6:06:29    45  45  45  45                         00/00/00   296   332
# 9   6:06:30    45  45  45  45                         00/00/00   768   357
# 10  6:06:31    45  45  45  45                    ZG   00/00/00   296   379
# ...
